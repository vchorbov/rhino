# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_palette("GnBu_d")
import folium
from folium import plugins
from folium.plugins import HeatMap
from datetime import datetime
from datetime import timedelta
import math
import random 
import timeit
from haversine import haversine
import sklearn as sk

# %%
brm = pd.read_csv("resources/bremen.csv")
frb = pd.read_csv("resources/freiburg.csv")
brm_hourly_driven = pd.read_csv("generated/brm_hourly_driven.csv")
frb_hourly_driven = pd.read_csv("generated/frb_hourly_driven.csv")
brm_weather = pd.read_csv("generated/bremen_weather.csv")
frb_weather = pd.read_csv("generated/freiburg_weather.csv")

# %%
brm_daily = brm_weather.groupby("day").agg({"trip_duration":"sum","precipitation":"sum","temperature":"mean"})

# %%
brm_daily
# Out:
#                                                 trip_duration  precipitation  \
# day
# 2019-01-20  0 days 00:17:00.0000000000 days 00:04:00.00000...            0.0
# 2019-01-21  0 days 00:09:00.0000000000 days 00:08:00.00000...            0.0
# 2019-01-22  0 days 00:11:00.0000000000 days 00:07:00.00000...            0.0
# 2019-01-23  0 days 00:10:00.0000000000 days 00:06:00.00000...            0.0
# 2019-01-24  0 days 00:16:00.0000000000 days 00:11:00.00000...            0.0
# ...                                                       ...            ...
# 2020-01-16  0 days 00:08:00.0000000000 days 00:11:00.00000...            0.0
# 2020-01-17  0 days 00:21:00.0000000000 days 00:24:00.00000...           17.9
# 2020-01-18  0 days 00:17:00.0000000000 days 00:13:00.00000...           31.1
# 2020-01-19  0 days 00:05:00.0000000000 days 00:04:00.00000...            1.9
# 2020-01-20  0 days 00:06:00.0000000000 days 00:06:00.00000...            0.0
#
#             temperature
# day
# 2019-01-20    -1.837374
# 2019-01-21    -2.236364
# 2019-01-22    -1.619653
# 2019-01-23    -4.686822
# 2019-01-24    -4.178431
# ...                 ...
# 2020-01-16     6.785681
# 2020-01-17     8.311515
# 2020-01-18     4.328495
# 2020-01-19     4.431013
# 2020-01-20     4.933007
#
# [363 rows x 3 columns]

# %%
for i in brm_daily.index:
    brm_daily.at[i,"trip_duration"] = brm_daily.at[i,"trip_duration"].seconds()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-35be9caa19cb> in <module>
# ----> 1 brm_daily["trip_duration"].apply(pd.Timedelta)
#       2 for i in brm_daily.index:
#       3     brm_daily.at[i,"trip_duration"] = brm_daily.at[i,"trip_duration"].seconds()
#
# E:\Programs\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: expected hh:mm:ss format before .

# %%
brm_daily
# Out:
#                                                 trip_duration  precipitation  \
# day
# 2019-01-20  0 days 00:17:00.0000000000 days 00:04:00.00000...            0.0
# 2019-01-21  0 days 00:09:00.0000000000 days 00:08:00.00000...            0.0
# 2019-01-22  0 days 00:11:00.0000000000 days 00:07:00.00000...            0.0
# 2019-01-23  0 days 00:10:00.0000000000 days 00:06:00.00000...            0.0
# 2019-01-24  0 days 00:16:00.0000000000 days 00:11:00.00000...            0.0
# ...                                                       ...            ...
# 2020-01-16  0 days 00:08:00.0000000000 days 00:11:00.00000...            0.0
# 2020-01-17  0 days 00:21:00.0000000000 days 00:24:00.00000...           17.9
# 2020-01-18  0 days 00:17:00.0000000000 days 00:13:00.00000...           31.1
# 2020-01-19  0 days 00:05:00.0000000000 days 00:04:00.00000...            1.9
# 2020-01-20  0 days 00:06:00.0000000000 days 00:06:00.00000...            0.0
#
#             temperature
# day
# 2019-01-20    -1.837374
# 2019-01-21    -2.236364
# 2019-01-22    -1.619653
# 2019-01-23    -4.686822
# 2019-01-24    -4.178431
# ...                 ...
# 2020-01-16     6.785681
# 2020-01-17     8.311515
# 2020-01-18     4.328495
# 2020-01-19     4.431013
# 2020-01-20     4.933007
#
# [363 rows x 3 columns]

# %%
x = brm_daily.values

# %%
x = brm_daily.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
demand = pd.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2e054eea2a5c> in <module>
#       1 x = brm_daily.values #returns a numpy array
# ----> 2 min_max_scaler = preprocessing.MinMaxScaler()
#       3 x_scaled = min_max_scaler.fit_transform(x)
#       4 demand = pd.DataFrame(x_scaled)
#
# NameError: name 'preprocessing' is not defined

# %%
plt.plot(brm_daily["precipitation"])
plt.show()

# %%
plt.plot(brm_daily["trip_duration"])
plt.show()

# %%
plt.plot(brm_daily["temperature"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-290878d3703a> in <module>
# ----> 1 plt.plot(brm_daily["temperature"])
#       2 plt.show()
#
# NameError: name 'brm_daily' is not defined
