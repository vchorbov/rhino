# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_palette("GnBu_d")
import folium
from folium import plugins
from folium.plugins import HeatMap
from datetime import datetime
from datetime import timedelta
import math
import random 
import timeit

# %%
brm = pd.read_csv("bremen.csv")
brm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157576 entries, 0 to 157575
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   day            157576 non-null  object
#  1   time           157576 non-null  object
#  2   b_number       157576 non-null  int64
#  3   city           157576 non-null  object
#  4   trip_duration  157576 non-null  object
#  5   orig_lat       157576 non-null  float64
#  6   orig_lng       157576 non-null  float64
#  7   dest_lat       157576 non-null  float64
#  8   dest_lng       157576 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 10.8+ MB

# %%
frb = pd.read_csv("freiburg.csv")
frb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127529 entries, 0 to 127528
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   day            127529 non-null  object
#  1   time           127529 non-null  object
#  2   b_number       127529 non-null  int64
#  3   city           127529 non-null  object
#  4   trip_duration  127529 non-null  object
#  5   orig_lat       127529 non-null  float64
#  6   orig_lng       127529 non-null  float64
#  7   dest_lat       127529 non-null  float64
#  8   dest_lng       127529 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 8.8+ MB

# %%
frb["orig_coordinates"] = list(zip(frb["orig_lat"].round(4),frb["orig_lng"].round(4)))
frb["dest_coordinates"] = list(zip(frb["dest_lat"].round(4),frb["dest_lng"].round(4)))

map = folium.Map(location=(47.997489, 7.842342),  tiles='Stamen Toner', 
                       zoom_start=9, control_scale=True, max_zoom=20)

# positions = list(frb["orig_coordinates"])
# for position in positions:
#     folium.CircleMarker(radius=5, location=position, popup='The Waterfront', 
#                                  color='crimson', fill_color='crimson').add_to(map)
folium.PolyLine(frb["orig_coordinates"],color="blue", weight=5, opacity=0.8, ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
